# %% [markdown]
# Cifar-10 이미지 분류v1

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)

plt.show()

# %%
# X data : 정규화 - 0~1 사이의 실수(float32)로 변환
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype(np.float32) / 255.

# %%
# y data : one-hot- encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Dropout, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), padding='same',activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,676,842
# Trainable params: 1,676,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-8), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v1.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.55119, saving model to best-cifar10-v1.h5
# 1250/1250 - 35s - loss: 1.8090 - accuracy: 0.3378 - val_loss: 1.5512 - val_accuracy: 0.4380 - 35s/epoch - 28ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.55119 to 1.35504, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.5016 - accuracy: 0.4543 - val_loss: 1.3550 - val_accuracy: 0.5180 - 22s/epoch - 18ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.35504 to 1.23974, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 1.3649 - accuracy: 0.5092 - val_loss: 1.2397 - val_accuracy: 0.5657 - 23s/epoch - 18ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.23974 to 1.18287, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 1.2567 - accuracy: 0.5517 - val_loss: 1.1829 - val_accuracy: 0.5775 - 23s/epoch - 18ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 1.18287
# 1250/1250 - 23s - loss: 1.1689 - accuracy: 0.5838 - val_loss: 1.1863 - val_accuracy: 0.5853 - 23s/epoch - 18ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.18287 to 1.01741, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 1.1022 - accuracy: 0.6140 - val_loss: 1.0174 - val_accuracy: 0.6453 - 21s/epoch - 17ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.01741 to 1.01055, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 1.0446 - accuracy: 0.6341 - val_loss: 1.0106 - val_accuracy: 0.6441 - 21s/epoch - 17ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.01055 to 0.94026, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 1.0002 - accuracy: 0.6488 - val_loss: 0.9403 - val_accuracy: 0.6711 - 21s/epoch - 17ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.94026 to 0.91183, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.9636 - accuracy: 0.6657 - val_loss: 0.9118 - val_accuracy: 0.6804 - 21s/epoch - 17ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.91183 to 0.90950, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.9283 - accuracy: 0.6775 - val_loss: 0.9095 - val_accuracy: 0.6853 - 22s/epoch - 17ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.90950 to 0.85996, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.9018 - accuracy: 0.6897 - val_loss: 0.8600 - val_accuracy: 0.7025 - 23s/epoch - 18ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.85996 to 0.82873, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.8710 - accuracy: 0.6960 - val_loss: 0.8287 - val_accuracy: 0.7121 - 22s/epoch - 18ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.82873 to 0.82329, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.8441 - accuracy: 0.7067 - val_loss: 0.8233 - val_accuracy: 0.7115 - 23s/epoch - 18ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.82329 to 0.79779, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.8360 - accuracy: 0.7111 - val_loss: 0.7978 - val_accuracy: 0.7233 - 21s/epoch - 17ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.79779 to 0.78975, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.8096 - accuracy: 0.7209 - val_loss: 0.7898 - val_accuracy: 0.7267 - 22s/epoch - 18ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.78975
# 1250/1250 - 22s - loss: 0.8008 - accuracy: 0.7243 - val_loss: 0.7999 - val_accuracy: 0.7215 - 22s/epoch - 17ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.78975 to 0.76501, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7873 - accuracy: 0.7292 - val_loss: 0.7650 - val_accuracy: 0.7353 - 22s/epoch - 18ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.76501 to 0.75420, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.7750 - accuracy: 0.7335 - val_loss: 0.7542 - val_accuracy: 0.7383 - 21s/epoch - 17ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.75420
# 1250/1250 - 21s - loss: 0.7631 - accuracy: 0.7403 - val_loss: 0.7570 - val_accuracy: 0.7378 - 21s/epoch - 17ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.75420 to 0.74903, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.7561 - accuracy: 0.7426 - val_loss: 0.7490 - val_accuracy: 0.7417 - 21s/epoch - 17ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.74903 to 0.74615, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.7457 - accuracy: 0.7452 - val_loss: 0.7461 - val_accuracy: 0.7446 - 21s/epoch - 17ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.74615 to 0.73501, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.7415 - accuracy: 0.7464 - val_loss: 0.7350 - val_accuracy: 0.7457 - 21s/epoch - 17ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.73501 to 0.72641, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.7302 - accuracy: 0.7519 - val_loss: 0.7264 - val_accuracy: 0.7489 - 21s/epoch - 17ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.72641 to 0.71594, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7210 - accuracy: 0.7542 - val_loss: 0.7159 - val_accuracy: 0.7521 - 22s/epoch - 18ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.71594 to 0.71236, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7178 - accuracy: 0.7577 - val_loss: 0.7124 - val_accuracy: 0.7535 - 22s/epoch - 18ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.71236 to 0.70731, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7054 - accuracy: 0.7614 - val_loss: 0.7073 - val_accuracy: 0.7566 - 22s/epoch - 18ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.70731
# 1250/1250 - 21s - loss: 0.7078 - accuracy: 0.7605 - val_loss: 0.7125 - val_accuracy: 0.7534 - 21s/epoch - 17ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.70731 to 0.70400, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7052 - accuracy: 0.7622 - val_loss: 0.7040 - val_accuracy: 0.7544 - 22s/epoch - 18ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.70400
# 1250/1250 - 22s - loss: 0.6958 - accuracy: 0.7646 - val_loss: 0.7706 - val_accuracy: 0.7428 - 22s/epoch - 17ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.70400 to 0.69716, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6973 - accuracy: 0.7662 - val_loss: 0.6972 - val_accuracy: 0.7650 - 22s/epoch - 17ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 0.69716 to 0.69400, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6886 - accuracy: 0.7684 - val_loss: 0.6940 - val_accuracy: 0.7636 - 22s/epoch - 18ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.69400
# 1250/1250 - 23s - loss: 0.6836 - accuracy: 0.7670 - val_loss: 0.7082 - val_accuracy: 0.7557 - 23s/epoch - 18ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.69400
# 1250/1250 - 21s - loss: 0.6767 - accuracy: 0.7727 - val_loss: 0.6988 - val_accuracy: 0.7631 - 21s/epoch - 17ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.69400
# 1250/1250 - 21s - loss: 0.6791 - accuracy: 0.7707 - val_loss: 0.7009 - val_accuracy: 0.7664 - 21s/epoch - 17ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 0.69400 to 0.68639, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.6691 - accuracy: 0.7726 - val_loss: 0.6864 - val_accuracy: 0.7729 - 21s/epoch - 17ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.68639
# 1250/1250 - 22s - loss: 0.6637 - accuracy: 0.7760 - val_loss: 0.6878 - val_accuracy: 0.7643 - 22s/epoch - 18ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.68639 to 0.68580, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6607 - accuracy: 0.7790 - val_loss: 0.6858 - val_accuracy: 0.7639 - 23s/epoch - 19ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.68580 to 0.67865, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6621 - accuracy: 0.7772 - val_loss: 0.6786 - val_accuracy: 0.7670 - 22s/epoch - 17ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.67865 to 0.67570, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.6534 - accuracy: 0.7809 - val_loss: 0.6757 - val_accuracy: 0.7697 - 21s/epoch - 17ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.67570
# 1250/1250 - 22s - loss: 0.6536 - accuracy: 0.7815 - val_loss: 0.7118 - val_accuracy: 0.7672 - 22s/epoch - 18ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.67570
# 1250/1250 - 23s - loss: 0.6516 - accuracy: 0.7821 - val_loss: 0.6899 - val_accuracy: 0.7669 - 23s/epoch - 18ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.67570
# 1250/1250 - 21s - loss: 0.6469 - accuracy: 0.7801 - val_loss: 0.6861 - val_accuracy: 0.7702 - 21s/epoch - 17ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.67570 to 0.65332, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.6467 - accuracy: 0.7839 - val_loss: 0.6533 - val_accuracy: 0.7755 - 21s/epoch - 17ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.65332
# 1250/1250 - 22s - loss: 0.6440 - accuracy: 0.7823 - val_loss: 0.6874 - val_accuracy: 0.7671 - 22s/epoch - 18ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.65332
# 1250/1250 - 23s - loss: 0.6422 - accuracy: 0.7835 - val_loss: 0.6690 - val_accuracy: 0.7772 - 23s/epoch - 18ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.65332
# 1250/1250 - 22s - loss: 0.6372 - accuracy: 0.7860 - val_loss: 0.6742 - val_accuracy: 0.7720 - 22s/epoch - 18ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.65332 to 0.64977, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6397 - accuracy: 0.7855 - val_loss: 0.6498 - val_accuracy: 0.7833 - 22s/epoch - 18ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.64977
# 1250/1250 - 23s - loss: 0.6315 - accuracy: 0.7890 - val_loss: 0.6608 - val_accuracy: 0.7763 - 23s/epoch - 18ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.64977
# 1250/1250 - 22s - loss: 0.6368 - accuracy: 0.7871 - val_loss: 0.6888 - val_accuracy: 0.7772 - 22s/epoch - 17ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.64977
# 1250/1250 - 21s - loss: 0.6355 - accuracy: 0.7894 - val_loss: 0.6983 - val_accuracy: 0.7671 - 21s/epoch - 17ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.64977 to 0.64829, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6302 - accuracy: 0.7873 - val_loss: 0.6483 - val_accuracy: 0.7798 - 22s/epoch - 18ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.64829
# 1250/1250 - 22s - loss: 0.6282 - accuracy: 0.7904 - val_loss: 0.6777 - val_accuracy: 0.7729 - 22s/epoch - 17ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.64829
# 1250/1250 - 22s - loss: 0.6265 - accuracy: 0.7913 - val_loss: 0.6604 - val_accuracy: 0.7769 - 22s/epoch - 18ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.64829
# 1250/1250 - 22s - loss: 0.6243 - accuracy: 0.7923 - val_loss: 0.6749 - val_accuracy: 0.7756 - 22s/epoch - 18ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.64829
# 1250/1250 - 22s - loss: 0.6203 - accuracy: 0.7942 - val_loss: 0.6858 - val_accuracy: 0.7756 - 22s/epoch - 17ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.64829
# 1250/1250 - 22s - loss: 0.6204 - accuracy: 0.7933 - val_loss: 0.7621 - val_accuracy: 0.7748 - 22s/epoch - 18ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss improved from 0.64829 to 0.64051, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6176 - accuracy: 0.7936 - val_loss: 0.6405 - val_accuracy: 0.7871 - 22s/epoch - 18ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.64051
# 1250/1250 - 22s - loss: 0.6202 - accuracy: 0.7950 - val_loss: 0.6555 - val_accuracy: 0.7861 - 22s/epoch - 17ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.64051
# 1250/1250 - 21s - loss: 0.6128 - accuracy: 0.7952 - val_loss: 0.6760 - val_accuracy: 0.7735 - 21s/epoch - 17ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.64051
# 1250/1250 - 21s - loss: 0.6138 - accuracy: 0.7970 - val_loss: 0.6895 - val_accuracy: 0.7738 - 21s/epoch - 17ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.64051
# 1250/1250 - 21s - loss: 0.6201 - accuracy: 0.7936 - val_loss: 0.6528 - val_accuracy: 0.7865 - 21s/epoch - 17ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.64051
# 1250/1250 - 22s - loss: 0.6170 - accuracy: 0.7939 - val_loss: 0.7042 - val_accuracy: 0.7713 - 22s/epoch - 18ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.64051
# 1250/1250 - 22s - loss: 0.6190 - accuracy: 0.7953 - val_loss: 0.6458 - val_accuracy: 0.7857 - 22s/epoch - 18ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.64051
# 1250/1250 - 21s - loss: 0.6099 - accuracy: 0.7956 - val_loss: 0.6618 - val_accuracy: 0.7814 - 21s/epoch - 17ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.64051
# 1250/1250 - 21s - loss: 0.6149 - accuracy: 0.7952 - val_loss: 0.6700 - val_accuracy: 0.7805 - 21s/epoch - 17ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.64051
# 1250/1250 - 22s - loss: 0.6090 - accuracy: 0.7940 - val_loss: 0.6467 - val_accuracy: 0.7862 - 22s/epoch - 18ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.64051
# 1250/1250 - 22s - loss: 0.6090 - accuracy: 0.7974 - val_loss: 0.6543 - val_accuracy: 0.7819 - 22s/epoch - 18ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6554 - accuracy: 0.7813
# [0.6554018259048462, 0.7813000082969666]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel("Epoch")
plt.show()
